# %%
name = "Omer bnb"
print("My name is", name)
# Out:
# My name is Omer

# %%
# Store and print name
name = "Omer"
print(name)

# Store and print age (integer)
age = 28
print(age)

# Store weight (INT) and print
weight = 70
print(weight)

# Store city, country, and favorite food
city = "Karachi"
country = "Pakistan"
favorite_food = "Biryani"

# Print all in one line
print(city, country, favorite_food)
# Out:
# Omer
# 28
# 70
# Karachi Pakistan Biryani

# %%
print("Name:", name)
print("Age:", age)
print("Weight:", weight)
print("City:", city, "Country:", country, "Favorite Food:", favorite_food)
# Out:
# Name: Omer
# Age: 28
# Weight: 70
# City: Karachi Country: Pakistan Favorite Food: Biryani

# %%
# Take two numbers
a = 8
b = 4

# Perform operations
print("Addition:", a + b)
print("Subtraction:", a - b)
print("Multiplication:", a * b)
print("Division:", a / b)
# Out:
# Addition: 12
# Subtraction: 4
# Multiplication: 32
# Division: 2.0

# %%
# Remainder and Power
print("Remainder:", a % b)
print("Power:", a ** b)

# Given values
x = 10
y = 3

# Print required operations
print("x + y =", x + y)
print("x - y =", x - y)
print("x * y =", x * y)
print("x / y =", x / y)
print("x % y =", x % y)
# Out:
# Remainder: 0
# Power: 4096
# x + y = 13
# x - y = 7
# x * y = 30
# x / y = 3.3333333333333335
# x % y = 1

# %%
# Integer to float
num_int = 10
num_float = float(num_int)

print("Integer:", num_int)
print("Converted to float:", num_float)
# Out:
# Integer: 10
# Converted to float: 10.0

# %%
# Float to integer
decimal_num = 7.8
converted_int = int(decimal_num)

print("Original float:", decimal_num)
print("Converted to integer:", converted_int)
# Out:
# Original float: 7.8
# Converted to integer: 7

# %%
# String to integer (user input)
num_str = input("Enter a number: ")
num_int2 = int(num_str)

print("String value:", num_str)
print("Converted to integer:", num_int2)
# Out:
# Enter a number:  45
# String value: 45
# Converted to integer: 45

# %%
Part 4: User Input
Ask the user for their name and print:
 👉 Hello, <name>!
Ask the user for their age and print:
 👉 You are <age> years old
Take two numbers from the user and print their sum.
# Out:
#   Cell In[10], line 3
#     👉 Hello, <name>!
#     ^
# SyntaxError: invalid character '👉' (U+1F449)

# %%
# Name (fixed)
name = "ijaz"
print("Hello,", name + "!")

# Age (fixed)
age = 25
print("You are", age, "years old")

# Take two numbers and print their sum
num1 = int(input("Enter first number: "))
num2 = int(input("Enter second number: "))

sum_result = num1 + num2
print("Sum:", sum_result)
# Out:
# Hello, ijaz!
# You are 25 years old
# Enter first number:  20
# Enter second number:  22
# Sum: 42

# %%
# Rectangle Area (fixed values)
length = 10
width = 5

area = length * width
print("Area of rectangle:", area)

# Square and Cube (fixed number)
number = 4

print("Square:", number ** 2)
print("Cube:", number ** 3)

# Average Marks (fixed values)
total_marks = 450
subjects = 5

average = total_marks / subjectsprint("Average marks:", average)
# Out:
# Area of rectangle: 50
# Square: 16
# Cube: 64
# Average marks: 90.0

# %%
celsius = 25  
fahrenheit = (celsius * 9/5) + 32
print("Fahrenheit:", fahrenheit)
# Out:
# Fahrenheit: 77.0

# %%
num = 9

if num % 2 == 0:
    print("Even number")
else:
    print("Odd number")
# Out:
# Odd number

# %%
8
# Out:
# 8

# %%
9
# Out:
# 9
